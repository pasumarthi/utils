# %%
print(2+3)
# Out:
# 5

# %%
name="jack"
name
# Out:
# 'jack'

# %%
print(name)
# Out:
# jack

# %%
del name

# %%
a=2
a.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2570a458a8a5> in <module>()
#       1 a=2
# ----> 2 a.dtype
#
# AttributeError: 'int' object has no attribute 'dtype'

# %%
s=4.0
s.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-abb95e415909> in <module>()
#       1 s=4.0
# ----> 2 s.type
#
# AttributeError: 'float' object has no attribute 'type'

# %%
str1="Suresh is learning Python"
str1
# Out:
# 'Suresh is learning Python'

# %%
print(str1[0:8])
print(str1[8:20])
print(str1[:20])
print("lenght:",len(str1[0:8]))
# Out:
# Suresh i
# s learning P
# Suresh is learning P
# lenght: 8

# %%
str2="Suresh"
str3=str2*3
print(str3)
print(str2+str2)
# Out:
# SureshSureshSuresh
# SureshSuresh

# %% [markdown]
# ###List      is an array with different data type
# Python index starts with 1

# %%
l1=["a",1,2.0]
print(l1)
print("out",l1[0],l1[2])
# Out:
# ['a', 1, 2.0]
# out a 2.0

# %%
l2=["b",5,7]
print(l1+l2)
l2[1]=9
print(l2)
# Out:
# ['a', 1, 2.0, 'b', 5, 7]
# ['b', 9, 7]

# %% [markdown]
# ### Tuples
# Ssequence data types
# Crated using parenthesis. Lists were created using square brackets
# Tuples can't be updated

# %%
t1=("c",3,9.0)
print(t1)
t1[2]
# Out:
# ('c', 3, 9.0)
# 9.0

# %% [markdown]
# ### Dictionaries
# Dictionaries have two major element types key and Value.
# Dictionaries are collection of key value pairs
# Each key is separated from its value by a colon (:), the items are separated by commas, and the whole thing is enclosed in curly braces.
# Keys are unique within a dictionary

# %%
d1={1:"Suresh",2:"Tejo",3:"Ram"}
d1
# Out:
# {1: 'Suresh', 2: 'Tejo', 3: 'Ram'}

# %%
print(d1[2])
#print(d1[7])
print(d1.keys())
print(d1.values())
# Out:
# Tejo
# dict_keys([1, 2, 3])
# dict_values(['Suresh', 'Tejo', 'Ram'])

# %% [markdown]
# ### for

# %%
l3=["abc","uyt",8,9.0]

for c1 in l3:
  print(c1*2)
# Out:
# abcabc
# uytuyt
# 16
# 18.0

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Function
# function can return values  no need to assign to any varaibles

# %%
def func1(v1,v2):
  v3 =v1*v2
  #print(v3)
  return v3

m=func1(6,7)
print("m :",m)
func1(3,4.0)
# Out:
# m 42
# 12.0

# %% [markdown]
# ### If else

# %%
 x=20
 if(x==2):
    print(x)
 else:
  print("sorry")
# Out:
# sorry

# %%
x=4
if(x<3):
  print("g1")
elif(x<5):
  print("g2")
else:
  print("g3")
# Out:
# g2

# %%
x=25
if(x<40):
  print("g1")
  if(x<35):
    print("g2")
    if(x<25):
      print("g3")
    else:
      print("g4")
  else:
    print("g5")
else:
  print("g6")
# Out:
# g1
# g2
# g4
